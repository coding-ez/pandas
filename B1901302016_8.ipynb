# %%
import http.client , urllib.request,urllib.parse
key = '8VWLI8UTAOR23GNX' # copy the write API key

t=int(22)

while True:
    t=t+1
    print ("temperature",t)
    params=urllib.parse.urlencode({'field1':t,'key':key})
    headers={"Content-type":"application/x-www-form-urlencoded","Accept":"text/plain"}
    con=http.client.HTTPConnection("api.thingspeak.com")
    con.request("POST","/update",params,headers)
    response=con.getresponse()
    print (response.status,response.reason)
    data=response.read()
    con.close()
# Out:
# temperature 23
# 200 OK
# temperature 24
# 200 OK
# temperature 25
# 200 OK
# temperature 26
# 200 OK
# temperature 27
# 200 OK
# temperature 28
# 200 OK
# temperature 29
# 200 OK
# temperature 30
# 200 OK
# temperature 31
# 200 OK
# temperature 32
# 200 OK
# temperature 33
# 200 OK
# temperature 34
# 200 OK
# temperature 35
# 200 OK
# temperature 36
# 200 OK
# temperature 37
# 200 OK
# temperature 38
# 200 OK
# temperature 39
# 200 OK
# temperature 40
# 200 OK
# temperature 41
# 200 OK
# temperature 42
# 200 OK
# temperature 43
# 200 OK
# temperature 44
# 200 OK
# temperature 45
# 200 OK
# temperature 46
# 200 OK
# temperature 47
# 200 OK
# temperature 48
# 200 OK
# temperature 49
# 200 OK
# temperature 50
# 200 OK
# temperature 51
# 200 OK
# temperature 52
# 200 OK
# temperature 53
# 200 OK
# temperature 54
# 200 OK
# temperature 55
# 200 OK
# temperature 56
# 200 OK
# temperature 57
# 200 OK
# temperature 58
# 200 OK
# temperature 59
# 200 OK
# temperature 60
# 200 OK
# temperature 61
# 200 OK
# temperature 62
# 200 OK
# temperature 63
# 200 OK
# temperature 64
# 200 OK
# temperature 65
# 200 OK
# temperature 66
# 200 OK
# temperature 67
# 200 OK
# temperature 68
# 200 OK
# temperature 69
# 200 OK
# temperature 70
# 200 OK
# temperature 71
# 200 OK
# temperature 72
# 200 OK
# temperature 73
# 200 OK
# temperature 74
# 200 OK
# temperature 75
# 200 OK
# temperature 76
# 200 OK
# temperature 77
# 200 OK
# temperature 78
# 200 OK
# temperature 79
# 200 OK
# temperature 80
# 200 OK
# temperature 81
# 200 OK
# temperature 82
# 200 OK
# temperature 83
# 200 OK
# temperature 84
# 200 OK
# temperature 85
# 200 OK
# temperature 86
# 200 OK
# temperature 87
# 200 OK
# temperature 88
# 200 OK
# temperature 89
# 200 OK
# temperature 90
# 200 OK
# temperature 91
# 200 OK
# temperature 92
# 200 OK
# temperature 93
# 200 OK
# temperature 94
# 200 OK
# temperature 95
# 200 OK
# temperature 96
# 200 OK
# temperature 97
# 200 OK
# temperature 98
# 200 OK
# temperature 99
# 200 OK
# temperature 100
# 200 OK
# temperature 101
# 200 OK
# temperature 102
# 200 OK
# temperature 103
# 200 OK
# temperature 104
# 200 OK
# temperature 105
# 200 OK
# temperature 106
# 200 OK
# temperature 107
# 200 OK
# temperature 108
# 200 OK
# temperature 109
# 200 OK
# temperature 110
# 200 OK
# temperature 111
# 200 OK
# temperature 112
# 200 OK
# temperature 113
# 200 OK
# temperature 114
# 200 OK
# temperature 115
# 200 OK
# temperature 116
# 200 OK
# temperature 117
# 200 OK
# temperature 118
# 200 OK
# temperature 119
# 200 OK
# temperature 120
# 200 OK
# temperature 121
# 200 OK
# temperature 122
# 200 OK
# temperature 123
# 200 OK
# temperature 124
# 200 OK
# temperature 125
# 200 OK
# temperature 126
# 200 OK
# temperature 127
# 200 OK
# temperature 128
# 200 OK
# temperature 129
# 200 OK
# temperature 130
# 200 OK
# temperature 131
# 200 OK
# temperature 132
# 200 OK
# temperature 133
# 200 OK
# temperature 134
# 200 OK
# temperature 135
# 200 OK
# temperature 136
# 200 OK
# temperature 137
# 200 OK
# temperature 138
# 200 OK
# temperature 139
# 200 OK
# temperature 140
# 200 OK
# temperature 141
# 200 OK
# temperature 142
# 200 OK
# temperature 143
# 200 OK
# temperature 144
# 200 OK
# temperature 145
# 200 OK
# temperature 146
# 200 OK
# temperature 147
# 200 OK
# temperature 148
# 200 OK
# temperature 149
# 200 OK
# temperature 150
# 200 OK
# temperature 151
# 200 OK
# temperature 152
# 200 OK
# temperature 153
# 200 OK
# temperature 154
# 200 OK
# temperature 155
# 200 OK
# temperature 156
# 200 OK
# temperature 157
# 200 OK
# temperature 158
# 200 OK
# temperature 159
# 200 OK
# temperature 160
# 200 OK
# temperature 161
# 200 OK
# temperature 162
# 200 OK
# temperature 163
# 200 OK
# temperature 164
# 200 OK
# temperature 165
# 200 OK
# temperature 166
# 200 OK
# temperature 167
# 200 OK
# temperature 168
# 200 OK
# temperature 169
# 200 OK
# temperature 170
# 200 OK
# temperature 171
# 200 OK
# temperature 172
# 200 OK
# temperature 173
# 200 OK
# temperature 174
# 200 OK
# temperature 175
# 200 OK
# temperature 176
# 200 OK
# temperature 177
# 200 OK
# temperature 178
# 200 OK
# temperature 179
# 200 OK
# temperature 180
# 200 OK
# temperature 181
# 200 OK
# temperature 182
# 200 OK
# temperature 183
# 200 OK
# temperature 184
# 200 OK
# temperature 185
# 200 OK
# temperature 186
# 200 OK
# temperature 187
# 200 OK
# temperature 188
# 200 OK
# temperature 189
# 200 OK
# temperature 190
# 200 OK
# temperature 191
# 200 OK
# temperature 192
# 200 OK
# temperature 193
# 200 OK
# temperature 194
# 200 OK
# temperature 195
# 200 OK
# temperature 196
# 200 OK
# temperature 197
# 200 OK
# temperature 198
# 200 OK
# temperature 199
# 200 OK
# temperature 200
# 200 OK
# temperature 201
# 200 OK
# temperature 202
# 200 OK
# temperature 203
# 200 OK
# temperature 204
# 200 OK
# temperature 205
# 200 OK
# temperature 206
# 200 OK
# temperature 207
# 200 OK
# temperature 208
# 200 OK
# temperature 209
# 200 OK
# temperature 210
# 200 OK
# temperature 211
# 200 OK
# temperature 212
# 200 OK
# temperature 213
# 200 OK
# temperature 214
# 200 OK
# temperature 215
# 200 OK
# temperature 216
# 200 OK
# temperature 217
# 200 OK
# temperature 218
# 200 OK
# temperature 219
# 200 OK
# temperature 220
# 200 OK
# temperature 221
# 200 OK
# temperature 222
# 200 OK
# temperature 223
# 200 OK
# temperature 224
# 200 OK
# temperature 225
# 200 OK
# temperature 226
# 200 OK
# temperature 227
# 200 OK
# temperature 228
# 200 OK
# temperature 229
# 200 OK
# temperature 230
# 200 OK
# temperature 231
# 200 OK
# temperature 232
# 200 OK
# temperature 233
# 200 OK
# temperature 234
# 200 OK
# temperature 235
# 200 OK
# temperature 236
# 200 OK
# temperature 237
# 200 OK
# temperature 238
# 200 OK
# temperature 239
# 200 OK
# temperature 240
# 200 OK
# temperature 241
# 200 OK
# temperature 242
# 200 OK
# temperature 243
# 200 OK
# temperature 244
# 200 OK
# temperature 245
# 200 OK
# temperature 246
# 200 OK
# temperature 247
# 200 OK
# temperature 248
# 200 OK
# temperature 249
# 200 OK
# temperature 250
# 200 OK
# temperature 251
# 200 OK
# temperature 252
# 200 OK
# temperature 253
# 200 OK
# temperature 254
# 200 OK
# temperature 255
# 200 OK
# temperature 256
# 200 OK
# temperature 257
# 200 OK
# temperature 258
# 200 OK
# temperature 259
# 200 OK
# temperature 260
# 200 OK
# temperature 261
# 200 OK
# temperature 262
# 200 OK
# temperature 263
# 200 OK
# temperature 264
# 200 OK
# temperature 265
# 200 OK
# temperature 266
# 200 OK
# temperature 267
# 200 OK
# temperature 268
# 200 OK
# temperature 269
# 200 OK
# temperature 270
# 200 OK
# temperature 271
# 200 OK
# temperature 272
# 200 OK
# temperature 273
# 200 OK
# temperature 274
# 200 OK
# temperature 275
# 200 OK
# temperature 276
# 200 OK
# temperature 277
# 200 OK
# temperature 278
# 200 OK
# temperature 279
# 200 OK
# temperature 280
# 200 OK
# temperature 281
# 200 OK
# temperature 282
# 200 OK
# temperature 283
# 200 OK
# temperature 284
# 200 OK
# temperature 285
# 200 OK
# temperature 286
# 200 OK
# temperature 287
# 200 OK
# temperature 288
# 200 OK
# temperature 289
# 200 OK
# temperature 290
# 200 OK
# temperature 291
# 200 OK
# temperature 292
# 200 OK
# temperature 293
# 200 OK
# temperature 294
# 200 OK
# temperature 295
# 200 OK
# temperature 296
# 200 OK
# temperature 297
# 200 OK
# temperature 298
# 200 OK
# temperature 299
# 200 OK
# temperature 300
# 200 OK
# temperature 301
# 200 OK
# temperature 302
# 200 OK
# temperature 303
# 200 OK
# temperature 304
# 200 OK
# temperature 305
# 200 OK
# temperature 306
# 200 OK
# temperature 307
# 200 OK
# temperature 308
# 200 OK
# temperature 309
# 200 OK
# temperature 310
# 200 OK
# temperature 311
# 200 OK
# temperature 312
# 200 OK
# temperature 313
# 200 OK
# temperature 314
# 200 OK
# temperature 315
# 200 OK
# temperature 316
# 200 OK
# temperature 317
# 200 OK
# temperature 318
# 200 OK
# temperature 319
# 200 OK
# temperature 320
# 200 OK
# temperature 321
# 200 OK
# temperature 322
# 200 OK
# temperature 323
# 200 OK
# temperature 324
# 200 OK
# temperature 325
# 200 OK
# temperature 326
# 200 OK
# temperature 327
# 200 OK
# temperature 328
# 200 OK
# temperature 329
# 200 OK
# temperature 330
# 200 OK
# temperature 331
# 200 OK
# temperature 332
# 200 OK
# temperature 333
# 200 OK
# temperature 334
# 200 OK
# temperature 335
# 200 OK
# temperature 336
# 200 OK
# temperature 337
# 200 OK
# temperature 338
# 200 OK
# temperature 339
# 200 OK
# temperature 340
# 200 OK
# temperature 341
# 200 OK
# temperature 342
# 200 OK
# temperature 343
# 200 OK
# temperature 344
# 200 OK
# temperature 345
# 200 OK
# temperature 346
# 200 OK
# temperature 347
# 200 OK
# temperature 348
# 200 OK
# temperature 349
# 200 OK
# temperature 350
# 200 OK
# temperature 351
# 200 OK
# temperature 352
# 200 OK
# temperature 353
# 200 OK
# temperature 354
# 200 OK
# temperature 355
# 200 OK
# temperature 356
# 200 OK
# temperature 357
# 200 OK
# temperature 358
# 200 OK
# temperature 359
# 200 OK
# temperature 360
# 200 OK
# temperature 361
# 200 OK
# temperature 362
# 200 OK
# temperature 363
# 200 OK
# temperature 364
# 200 OK
# temperature 365
# 200 OK
# temperature 366
# 200 OK
# temperature 367
# 200 OK
# temperature 368
# 200 OK
# temperature 369
# 200 OK
# temperature 370
# 200 OK
# temperature 371
# 200 OK
# temperature 372
# 200 OK
# temperature 373
# 200 OK
# temperature 374
# 200 OK
# temperature 375
# 200 OK
# temperature 376
# 200 OK
# temperature 377
# 200 OK
# temperature 378
# 200 OK
# temperature 379
# 200 OK
# temperature 380
# 200 OK
# temperature 381
# 200 OK
# temperature 382
# 200 OK
# temperature 383
# 200 OK
# temperature 384
# 200 OK
# temperature 385
# 200 OK
# temperature 386
# 200 OK
# temperature 387
# 200 OK
# temperature 388
# 200 OK
# temperature 389
# 200 OK
# temperature 390
# 200 OK
# temperature 391
# 200 OK
# temperature 392
# 200 OK
# temperature 393
# 200 OK
# temperature 394
# 200 OK
# temperature 395
# 200 OK
# temperature 396
# 200 OK
# temperature 397
# 200 OK
# temperature 398
# 200 OK
# temperature 399
# 200 OK
# temperature 400
# 200 OK
# temperature 401
# 200 OK
# temperature 402
# 200 OK
# temperature 403
# 200 OK
# temperature 404
# 200 OK
# temperature 405
# 200 OK
# temperature 406
# 200 OK
# temperature 407
# 200 OK
# temperature 408
# 200 OK
# temperature 409
# 200 OK
# temperature 410
# 200 OK
# temperature 411
# 200 OK
# temperature 412
# 200 OK
# temperature 413
# 200 OK
# temperature 414
# 200 OK
# temperature 415
# 200 OK
# temperature 416
# 200 OK
# temperature 417
# 200 OK
# temperature 418
# 200 OK
# temperature 419
# 200 OK
# temperature 420
# 200 OK
# temperature 421
# 200 OK
# temperature 422
# 200 OK
# temperature 423
# 200 OK
# temperature 424
# 200 OK
# temperature 425
# 200 OK
# temperature 426
# 200 OK
# temperature 427
# 200 OK
# temperature 428
# 200 OK
# temperature 429
# 200 OK
# temperature 430
# 200 OK
# temperature 431
# 200 OK
# temperature 432
# 200 OK
# temperature 433
# 200 OK
# temperature 434
# 200 OK
# temperature 435
# 200 OK
# temperature 436
# 200 OK
# temperature 437
# 200 OK
# temperature 438
# 200 OK
# temperature 439
# 200 OK
# temperature 440
# 200 OK
# temperature 441
# 200 OK
# temperature 442
# 200 OK
# temperature 443
# 200 OK
# temperature 444
# 200 OK
# temperature 445
# 200 OK
# temperature 446
# 200 OK
# temperature 447
# 200 OK
# temperature 448
# 200 OK
# temperature 449
# 200 OK
# temperature 450
# 200 OK
# temperature 451
# 200 OK
# temperature 452
# 200 OK
# temperature 453
# 200 OK
# temperature 454
# 200 OK
# temperature 455
# 200 OK
# temperature 456
# 200 OK
# temperature 457
# 200 OK
# temperature 458
# 200 OK
# temperature 459
# 200 OK
# temperature 460
# 200 OK
# temperature 461
# 200 OK
# temperature 462
# 200 OK
# temperature 463
# 200 OK
# temperature 464
# 200 OK
# temperature 465
# 200 OK
# temperature 466
# 200 OK
# temperature 467
# 200 OK
# temperature 468
# 200 OK
# temperature 469
# 200 OK
# temperature 470
# 200 OK
# temperature 471
# 200 OK
# temperature 472
# 200 OK
# temperature 473
# 200 OK
# temperature 474
# 200 OK
# temperature 475
# 200 OK
# temperature 476
# 200 OK
# temperature 477
# 200 OK
# temperature 478
# 200 OK
# temperature 479
# 200 OK
# temperature 480
# 200 OK
# temperature 481
# 200 OK
# temperature 482
# 200 OK
# temperature 483
# 200 OK
# temperature 484
# 200 OK
# temperature 485
# 200 OK
# temperature 486
# 200 OK
# temperature 487
# 200 OK
# temperature 488
# 200 OK
# temperature 489
# 200 OK
# temperature 490
# 200 OK
# temperature 491
# 200 OK
# temperature 492
# 200 OK
# temperature 493
# 200 OK
# temperature 494
# 200 OK
# temperature 495
# 200 OK
# temperature 496
# 200 OK
# temperature 497
# 200 OK
# temperature 498
# 200 OK
# temperature 499
# 200 OK
# temperature 500
# 200 OK
# temperature 501
# 200 OK
# temperature 502
# 200 OK
# temperature 503
# 200 OK
# temperature 504
# 200 OK
# temperature 505
# 200 OK
# temperature 506
# 200 OK
# temperature 507
# 200 OK
# temperature 508
# 200 OK
# temperature 509
# 200 OK
# temperature 510
# 200 OK
# temperature 511
# 200 OK
# temperature 512
# 200 OK
# temperature 513
# 200 OK
# temperature 514
# 200 OK
# temperature 515
# 200 OK
# temperature 516
# 200 OK
# temperature 517
# 200 OK
# temperature 518
# 200 OK
# temperature 519
# 200 OK
# temperature 520
# 200 OK
# temperature 521
# 200 OK
# temperature 522
# 200 OK
# temperature 523
# 200 OK
# temperature 524
# 200 OK
# temperature 525
# 200 OK
# temperature 526
# 200 OK
# temperature 527
# 200 OK
# temperature 528
# 200 OK
# temperature 529
# 200 OK
# temperature 530
# 200 OK
# temperature 531
# 200 OK
# temperature 532
# 200 OK
# temperature 533
# 200 OK
# temperature 534
# 200 OK
# temperature 535
# 200 OK
# temperature 536
# 200 OK
# temperature 537
# 200 OK
# temperature 538
# 200 OK
# temperature 539
# 200 OK
# temperature 540
# 200 OK
# temperature 541
# 200 OK
# temperature 542
# 200 OK
# temperature 543
# 200 OK
# temperature 544
# 200 OK
# temperature 545
# 200 OK
# temperature 546
# 200 OK
# temperature 547
# 200 OK
# temperature 548
# 200 OK
# temperature 549
# 200 OK
# temperature 550
# 200 OK
# temperature 551
# 200 OK
# temperature 552
# 200 OK
# temperature 553
# 200 OK
# temperature 554
# 200 OK
# temperature 555
# 200 OK
# temperature 556
# 200 OK
# temperature 557
# 200 OK
# temperature 558
# 200 OK
# temperature 559
# 200 OK
# temperature 560
# 200 OK
# temperature 561
# 200 OK
# temperature 562
# 200 OK
# temperature 563
# 200 OK
# temperature 564
# 200 OK
# temperature 565
# 200 OK
# temperature 566
# 200 OK
# temperature 567
# 200 OK
# temperature 568
# 200 OK
# temperature 569
# 200 OK
# temperature 570
# 200 OK
# temperature 571
# 200 OK
# temperature 572
# 200 OK
# temperature 573
# 200 OK
# temperature 574
# 200 OK
# temperature 575
# 200 OK
# temperature 576
# 200 OK
# temperature 577
# 200 OK
# temperature 578
# 200 OK
# temperature 579
# 200 OK
# temperature 580
# 200 OK
# temperature 581
# 200 OK
# temperature 582
# 200 OK
# temperature 583
# 200 OK
# temperature 584
# 200 OK
# temperature 585
# 200 OK
# temperature 586
# 200 OK
# temperature 587
# 200 OK
# temperature 588
# 200 OK
# temperature 589
# 200 OK
# temperature 590
# 200 OK
# temperature 591
# 200 OK
# temperature 592
# 200 OK
# temperature 593
# 200 OK
# temperature 594
# 200 OK
# temperature 595
# 200 OK
# temperature 596
# 200 OK
# temperature 597
# 200 OK
# temperature 598
# 200 OK
# temperature 599
# 200 OK
# temperature 600
# 200 OK
# temperature 601
# 200 OK
# temperature 602
# 200 OK
# temperature 603
# 200 OK
# temperature 604
# 200 OK
# temperature 605
# 200 OK
# temperature 606
# 200 OK
# temperature 607
# 200 OK
# temperature 608
# 200 OK
# temperature 609
# 200 OK
# temperature 610
# 200 OK
# temperature 611
# 200 OK
# temperature 612
# 200 OK
# temperature 613
# 200 OK
# temperature 614
# 200 OK
# temperature 615
# 200 OK
# temperature 616
# 200 OK
# temperature 617
# 200 OK
# temperature 618
# 200 OK
# temperature 619
# 200 OK
# temperature 620
# 200 OK
# temperature 621
# 200 OK
# temperature 622
# 200 OK
# temperature 623
# 200 OK
# temperature 624
# 200 OK
# temperature 625
# 200 OK
# temperature 626
# 200 OK
# temperature 627
# 200 OK
# temperature 628
# 200 OK
# temperature 629
# 200 OK
# temperature 630
# 200 OK
# temperature 631
# 200 OK
# temperature 632
# 200 OK
# temperature 633
# 200 OK
# temperature 634
# 200 OK
# temperature 635
# 200 OK
# temperature 636
# 200 OK
# temperature 637
# 200 OK
# temperature 638
# 200 OK
# temperature 639
# 200 OK
# temperature 640
# 200 OK
# temperature 641
# 200 OK
# temperature 642
# 200 OK
# temperature 643
# 200 OK
# temperature 644
# 200 OK
# temperature 645
# 200 OK
# temperature 646
# 200 OK
# temperature 647
# 200 OK
# temperature 648
# 200 OK
# temperature 649
# 200 OK
# temperature 650
# 200 OK
# temperature 651
# 200 OK
# temperature 652
# 200 OK
# temperature 653
# 200 OK
# temperature 654
# 200 OK
# temperature 655
# 200 OK
# temperature 656
# 200 OK
# temperature 657
# 200 OK
# temperature 658
# 200 OK
# temperature 659
# 200 OK
# temperature 660
# 200 OK
# temperature 661
# 200 OK
# temperature 662
# 200 OK
# temperature 663
# 200 OK
# temperature 664
# 200 OK
# temperature 665
# 200 OK
# temperature 666
# 200 OK
# temperature 667
# 200 OK
# temperature 668
# 200 OK
# temperature 669
# 200 OK
# temperature 670
# 200 OK
# temperature 671
# 200 OK
# temperature 672
# 200 OK
# temperature 673
# 200 OK
# temperature 674
# 200 OK
# temperature 675
# 200 OK
# temperature 676
# 200 OK
# temperature 677
# 200 OK
# temperature 678
# 200 OK
# temperature 679
# 200 OK
# temperature 680
# 200 OK
# temperature 681
# 200 OK
# temperature 682
# 200 OK
# temperature 683
# 200 OK
# temperature 684
# 200 OK
# temperature 685
# 200 OK
# temperature 686
# 200 OK
# temperature 687
# 200 OK
# temperature 688
# 200 OK
# temperature 689
# 200 OK
# temperature 690
# 200 OK
# temperature 691
# 200 OK
# temperature 692
# 200 OK
# temperature 693
# 200 OK
# temperature 694
# 200 OK
# temperature 695
# 200 OK
# temperature 696
# 200 OK
# temperature 697
# 200 OK
# temperature 698
# 200 OK
# temperature 699
# 200 OK
# temperature 700
# 200 OK
# temperature 701
# 200 OK
# temperature 702
# 200 OK
# temperature 703
# 200 OK
# temperature 704
# 200 OK
# temperature 705
# 200 OK
# temperature 706
# 200 OK
# temperature 707
# 200 OK
# temperature 708
# 200 OK
# temperature 709
# 200 OK
# temperature 710
# 200 OK
# temperature 711
# 200 OK
# temperature 712
# 200 OK
# temperature 713
# 200 OK
# temperature 714
# 200 OK
# temperature 715
# 200 OK
# temperature 716
# 200 OK
# temperature 717
# 200 OK
# temperature 718
# 200 OK
# temperature 719
# 200 OK
# temperature 720
# 200 OK
# temperature 721
# 200 OK
# temperature 722
# 200 OK
# temperature 723
# 200 OK
# temperature 724
# 200 OK
# temperature 725
# 200 OK
# temperature 726
# 200 OK
# temperature 727
# 200 OK
# temperature 728
# 200 OK
# temperature 729
# 200 OK
# temperature 730
# 200 OK
# temperature 731
# 200 OK
# temperature 732
# 200 OK
# temperature 733
# 200 OK
# temperature 734
# 200 OK
# temperature 735
# 200 OK
# temperature 736
# 200 OK
# temperature 737
# 200 OK
# temperature 738
# 200 OK
# temperature 739
# 200 OK
# temperature 740
# 200 OK
# temperature 741
# 200 OK
# temperature 742
# 200 OK
# temperature 743
# 200 OK
# temperature 744
# 200 OK
# temperature 745
# 200 OK
# temperature 746
# 200 OK
# temperature 747
# 200 OK
# temperature 748
# 200 OK
# temperature 749
# 200 OK
# temperature 750
# 200 OK
# temperature 751
# 200 OK
# temperature 752
# 200 OK
# temperature 753
# 200 OK
# temperature 754
# 200 OK
# temperature 755
# 200 OK
# temperature 756
# 200 OK
# temperature 757
# 200 OK
# temperature 758
# 200 OK
# temperature 759
# 200 OK
# temperature 760
# 200 OK
# temperature 761
# 200 OK
# temperature 762
# 200 OK
# temperature 763
# 200 OK
# temperature 764
# 200 OK
# temperature 765
# 200 OK
# temperature 766
# 200 OK
# temperature 767
# 200 OK
# temperature 768
# 200 OK
# temperature 769
# 200 OK
# temperature 770
# 200 OK
# temperature 771
# 200 OK
# temperature 772
# 200 OK
# temperature 773
# 200 OK
# temperature 774
# 200 OK
# temperature 775
# 200 OK
# temperature 776
# 200 OK
# temperature 777
# 200 OK
# temperature 778
# 200 OK
# temperature 779
# 200 OK
# temperature 780
# 200 OK
# temperature 781
# 200 OK
# temperature 782
# 200 OK
# temperature 783
# 200 OK
# temperature 784
# 200 OK
# temperature 785
# 200 OK
# temperature 786
# 200 OK
# temperature 787
# 200 OK
# temperature 788
# 200 OK
# temperature 789
# 200 OK
# temperature 790
# 200 OK
# temperature 791
# 200 OK
# temperature 792
# 200 OK
# temperature 793
# 200 OK
# temperature 794
# 200 OK
# temperature 795
# 200 OK
# temperature 796
# 200 OK
# temperature 797
# 200 OK
# temperature 798
# 200 OK
# temperature 799
# 200 OK
# temperature 800
# 200 OK
# temperature 801
# 200 OK
# temperature 802
# 200 OK
# temperature 803
# 200 OK
# temperature 804
# 200 OK
# temperature 805
# 200 OK
# temperature 806
# 200 OK
# temperature 807
# 200 OK
# temperature 808
# 200 OK
# temperature 809
# 200 OK
# temperature 810
# 200 OK
# temperature 811
# 200 OK
# temperature 812
# 200 OK
# temperature 813
# 200 OK
# temperature 814
# 200 OK
# temperature 815
# 200 OK
# temperature 816
# 200 OK
# temperature 817
# 200 OK
# temperature 818
# 200 OK
# temperature 819
# 200 OK
# temperature 820
# 200 OK
# temperature 821
# 200 OK
# temperature 822
# 200 OK
# temperature 823
# 200 OK
# temperature 824
# 200 OK
# temperature 825
# 200 OK
# temperature 826
# 200 OK
# temperature 827
# 200 OK
# temperature 828
# 200 OK
# temperature 829
# 200 OK
# temperature 830
# 200 OK
# temperature 831
# 200 OK
# temperature 832
# 200 OK
# temperature 833
# 200 OK
# temperature 834
# 200 OK
# temperature 835
# 200 OK
# temperature 836
# 200 OK
# temperature 837
# 200 OK
# temperature 838
# 200 OK
# temperature 839
# 200 OK
# temperature 840
# 200 OK
# temperature 841
# 200 OK
# temperature 842
# 200 OK
# temperature 843
# 200 OK
# temperature 844
# 200 OK
# temperature 845
# 200 OK
# temperature 846
# 200 OK
# temperature 847
# 200 OK
# temperature 848
# 200 OK
# temperature 849
# 200 OK
# temperature 850
# 200 OK
# temperature 851
# 200 OK
# temperature 852
# 200 OK
# temperature 853
# 200 OK
# temperature 854
# 200 OK
# temperature 855
# 200 OK
# temperature 856
# 200 OK
# temperature 857
# 200 OK
# temperature 858
# 200 OK
# temperature 859
# 200 OK
# temperature 860
# 200 OK
# temperature 861
# 200 OK
# temperature 862
# 200 OK
# temperature 863
# 200 OK
# temperature 864
# 200 OK
# temperature 865
# 200 OK
# temperature 866
# 200 OK
# temperature 867
# 200 OK
# temperature 868
# 200 OK
# temperature 869
# 200 OK
# temperature 870
# 200 OK
# temperature 871
# 200 OK
# temperature 872
# 200 OK
# temperature 873
# 200 OK
# temperature 874
# 200 OK
# temperature 875
# 200 OK
# temperature 876
# 200 OK
# temperature 877
# 200 OK
# temperature 878
# 200 OK
# temperature 879
# 200 OK
# temperature 880
# 200 OK
# temperature 881
# 200 OK
# temperature 882
# 200 OK
# temperature 883
# 200 OK
# temperature 884
# 200 OK
# temperature 885
# 200 OK
# temperature 886
# 200 OK
# temperature 887
# 200 OK
# temperature 888
# 200 OK
# temperature 889
# 200 OK
# temperature 890
# 200 OK
# temperature 891
# 200 OK
# temperature 892
# 200 OK
# temperature 893
# 200 OK
# temperature 894
# 200 OK
# temperature 895
# 200 OK
# temperature 896
# 200 OK
# temperature 897
# 200 OK
# temperature 898
# 200 OK
# temperature 899
# 200 OK
# temperature 900
# 200 OK
# temperature 901
# 200 OK
# temperature 902
# 200 OK
# temperature 903
# 200 OK
# temperature 904
# 200 OK
# temperature 905
# 200 OK
# temperature 906
# 200 OK
# temperature 907
# 200 OK
# temperature 908
# 200 OK
# temperature 909
# 200 OK
# temperature 910
# 200 OK
# temperature 911
# 200 OK
# temperature 912
# 200 OK
# temperature 913
# 200 OK
# temperature 914
# 200 OK
# temperature 915
# 200 OK
# temperature 916
# 200 OK
# temperature 917
# 200 OK
# temperature 918
# 200 OK
# temperature 919
# 200 OK
# temperature 920
# 200 OK
# temperature 921
# 200 OK
# temperature 922
# 200 OK
# temperature 923
# 200 OK
# temperature 924
# 200 OK
# temperature 925
# 200 OK
# temperature 926
# 200 OK
# temperature 927
# 200 OK
# temperature 928
# 200 OK
# temperature 929
# 200 OK
# temperature 930
# 200 OK
# temperature 931
# 200 OK
# temperature 932
# 200 OK
# temperature 933
# 200 OK
# temperature 934
# 200 OK
# temperature 935
# 200 OK
# temperature 936
# 200 OK
# temperature 937
# 200 OK
# temperature 938
# 200 OK
# temperature 939
# 200 OK
# temperature 940
# 200 OK
# temperature 941
# 200 OK
# temperature 942
# 200 OK
# temperature 943
# 200 OK
# temperature 944
# 200 OK
# temperature 945
# 200 OK
# temperature 946
# 200 OK
# temperature 947
# 200 OK
# temperature 948
# 200 OK
# temperature 949
# 200 OK
# temperature 950
# 200 OK
# temperature 951
# 200 OK
# temperature 952
# 200 OK
# temperature 953
# 200 OK
# temperature 954
# 200 OK
# temperature 955
# 200 OK
# temperature 956
# 200 OK
# temperature 957
# 200 OK
# temperature 958
# 200 OK
# temperature 959
# 200 OK
# temperature 960
# 200 OK
# temperature 961
# 200 OK
# temperature 962
# 200 OK
# temperature 963
# 200 OK
# temperature 964
# 200 OK
# temperature 965
# 200 OK
# temperature 966
# 200 OK
# temperature 967
# 200 OK
# temperature 968
# 200 OK
# temperature 969
# 200 OK
# temperature 970
# 200 OK
# temperature 971
# 200 OK
# temperature 972
# 200 OK
# temperature 973
# 200 OK
# temperature 974
# 200 OK
# temperature 975
# 200 OK
# temperature 976
# 200 OK
# temperature 977
# 200 OK
# temperature 978
# 200 OK
# temperature 979
# 200 OK
# temperature 980
# 200 OK
# temperature 981
# 200 OK
# temperature 982
# 200 OK
# temperature 983
# 200 OK
# temperature 984
# 200 OK
# temperature 985
# 200 OK
# temperature 986
# 200 OK
# temperature 987
# 200 OK
# temperature 988
# 200 OK
# temperature 989
# 200 OK
# temperature 990
# 200 OK
# temperature 991
# 200 OK
# temperature 992
# 200 OK
# temperature 993
# 200 OK
# temperature 994
# 200 OK
# temperature 995
# 200 OK
# temperature 996
# 200 OK
# temperature 997
# 200 OK
# temperature 998
# 200 OK
# temperature 999
# 200 OK
# temperature 1000
# 200 OK
# temperature 1001
# 200 OK
# temperature 1002
# 200 OK
# temperature 1003
# 200 OK
# temperature 1004
# 200 OK
# temperature 1005
# 200 OK
# temperature 1006
# 200 OK
# temperature 1007
# 200 OK
# temperature 1008
# 200 OK
# temperature 1009
# 200 OK
# temperature 1010
# 200 OK
# temperature 1011
# 200 OK
# temperature 1012
# 200 OK
# temperature 1013
# 200 OK
# temperature 1014
# 200 OK
# temperature 1015
# 200 OK
# temperature 1016
# 200 OK
# temperature 1017
# 200 OK
# temperature 1018
# 200 OK
# temperature 1019
# 200 OK
# temperature 1020
# 200 OK
# temperature 1021
# 200 OK
# temperature 1022
# 200 OK
# temperature 1023
# 200 OK
# temperature 1024
# 200 OK
# temperature 1025
# 200 OK
# temperature 1026
# 200 OK
# temperature 1027
# 200 OK
# temperature 1028
# 200 OK
# temperature 1029
# 200 OK
# temperature 1030
# 200 OK
# temperature 1031
# 200 OK
# temperature 1032
# 200 OK
# temperature 1033
# 200 OK
# temperature 1034
# 200 OK
# temperature 1035
# 200 OK
# temperature 1036
# 200 OK
# temperature 1037
# 200 OK
# temperature 1038
# 200 OK
# temperature 1039
# 200 OK
# temperature 1040
# 200 OK
# temperature 1041
# 200 OK
# temperature 1042
# 200 OK
# temperature 1043
# 200 OK
# temperature 1044
# 200 OK
# temperature 1045
# 200 OK
# temperature 1046
# 200 OK
# temperature 1047
# 200 OK
# temperature 1048
# 200 OK
# temperature 1049
# 200 OK
# temperature 1050
# 200 OK
# temperature 1051
# 200 OK
# temperature 1052
# 200 OK
# temperature 1053
# 200 OK
# temperature 1054
# 200 OK
# temperature 1055
# 200 OK
# temperature 1056
# 200 OK
# temperature 1057
# 200 OK
# temperature 1058
# 200 OK
# temperature 1059
# 200 OK
# temperature 1060
# 200 OK
# temperature 1061
# 200 OK
# temperature 1062
# 200 OK
# temperature 1063
# 200 OK
# temperature 1064
# 200 OK
# temperature 1065
# 200 OK
# temperature 1066
# 200 OK
# temperature 1067
# 200 OK
# temperature 1068
# 200 OK
# temperature 1069
# 200 OK
# temperature 1070
# 200 OK
# temperature 1071
# 200 OK
# temperature 1072
# 200 OK
# temperature 1073
# 200 OK
# temperature 1074
# 200 OK
# temperature 1075
# 200 OK
# temperature 1076
# 200 OK
# temperature 1077
# 200 OK
# temperature 1078
# 200 OK
# temperature 1079
# 200 OK
# temperature 1080
# 200 OK
# temperature 1081
# 200 OK
# temperature 1082
# 200 OK
# temperature 1083
# 200 OK
# temperature 1084
# 200 OK
# temperature 1085
# 200 OK
# temperature 1086
# 200 OK
# temperature 1087
# 200 OK
# temperature 1088
# 200 OK
# temperature 1089
# 200 OK
# temperature 1090
# 200 OK
# temperature 1091
# 200 OK
# temperature 1092
# 200 OK
# temperature 1093
# 200 OK
# temperature 1094
# 200 OK
# temperature 1095
# 200 OK
# temperature 1096
# 200 OK
# temperature 1097
# 200 OK
# temperature 1098
# 200 OK
# temperature 1099
# 200 OK
# temperature 1100
# 200 OK
# temperature 1101
# 200 OK
# temperature 1102
# 200 OK
# temperature 1103
# 200 OK
# temperature 1104
# 200 OK
# temperature 1105
# 200 OK
# temperature 1106
# 200 OK
# temperature 1107
# 200 OK
# temperature 1108
# 200 OK
# temperature 1109
# 200 OK
# temperature 1110
# 200 OK
# temperature 1111
# 200 OK
# temperature 1112
# 200 OK
# temperature 1113
# 200 OK
# temperature 1114
# 200 OK
# temperature 1115
# 200 OK
# temperature 1116
# 200 OK
# temperature 1117
# 200 OK
# temperature 1118
# 200 OK
# temperature 1119
# 200 OK
# temperature 1120
# 200 OK
# temperature 1121
# 200 OK
# temperature 1122
# 200 OK
# temperature 1123
# 200 OK
# temperature 1124
# 200 OK
# temperature 1125
# 200 OK
# temperature 1126
# 200 OK
# temperature 1127
# 200 OK
# temperature 1128
# 200 OK
# temperature 1129
# 200 OK
# temperature 1130
# 200 OK
# temperature 1131
# 200 OK
# temperature 1132
# 200 OK
# temperature 1133
# 200 OK
# temperature 1134
# 200 OK
# temperature 1135
# 200 OK
# temperature 1136
# 200 OK
# temperature 1137
# 200 OK
# temperature 1138
# 200 OK
# temperature 1139
# 200 OK
# temperature 1140
# 200 OK
# temperature 1141
# 200 OK
# temperature 1142
# 200 OK
# temperature 1143
# 200 OK
# temperature 1144
# 200 OK
# temperature 1145
# 200 OK
# temperature 1146
# 200 OK
# temperature 1147
# 200 OK
# temperature 1148
# 200 OK
# temperature 1149
# 200 OK
# temperature 1150
# 200 OK
# temperature 1151
# 200 OK
# temperature 1152
# 200 OK
# temperature 1153
# 200 OK
# temperature 1154
# 200 OK
# temperature 1155
# 200 OK
# temperature 1156
# 200 OK
# temperature 1157
# 200 OK
# temperature 1158
# 200 OK
# temperature 1159
# 200 OK
# temperature 1160
# 200 OK
# temperature 1161
# 200 OK
# temperature 1162
# 200 OK
# temperature 1163
# 200 OK
# temperature 1164
# 200 OK
# temperature 1165
# 200 OK
# temperature 1166
# 200 OK
# temperature 1167
# 200 OK
# temperature 1168
# 200 OK
# temperature 1169
# 200 OK
# temperature 1170
# 200 OK
# temperature 1171
# 200 OK
# temperature 1172
# 200 OK
# temperature 1173
# 200 OK
# temperature 1174
# 200 OK
# temperature 1175
# 200 OK
# temperature 1176
# 200 OK
# temperature 1177
# 200 OK
# temperature 1178
# 200 OK
# temperature 1179
# 200 OK
# temperature 1180
# 200 OK
# temperature 1181
# 200 OK
# temperature 1182
# 200 OK
# temperature 1183
# 200 OK
# temperature 1184
# 200 OK
# temperature 1185
# 200 OK
# temperature 1186
# 200 OK
# temperature 1187
# 200 OK
# temperature 1188
# 200 OK
# temperature 1189
# 200 OK
# temperature 1190
# 200 OK
# temperature 1191
# 200 OK
# temperature 1192
# 200 OK
# temperature 1193
# 200 OK
# temperature 1194
# 200 OK
# temperature 1195
# 200 OK
# temperature 1196
# 200 OK
# temperature 1197
# 200 OK
# temperature 1198
# 200 OK
# temperature 1199
# 200 OK
# temperature 1200
# 200 OK
# temperature 1201
# 200 OK
# temperature 1202
# 200 OK
# temperature 1203
# 200 OK
# temperature 1204
# 200 OK
# temperature 1205
# 200 OK
# temperature 1206
# 200 OK
# temperature 1207
# 200 OK
# temperature 1208
# 200 OK
# temperature 1209
# 200 OK
# temperature 1210
# 200 OK
# temperature 1211
# 200 OK
# temperature 1212
# 200 OK
# temperature 1213
# 200 OK
# temperature 1214
# 200 OK
# temperature 1215
# 200 OK
# temperature 1216
# 200 OK
# temperature 1217
# 200 OK
# temperature 1218
# 200 OK
# temperature 1219
# 200 OK
# temperature 1220
# 200 OK
# temperature 1221
# 200 OK
# temperature 1222
# 200 OK
# temperature 1223
# 200 OK
# temperature 1224
# 200 OK
# temperature 1225
# 200 OK
# temperature 1226
# 200 OK
# temperature 1227
# 200 OK
# temperature 1228
# 200 OK
# temperature 1229
# 200 OK
# temperature 1230
# 200 OK
# temperature 1231
# 200 OK
# temperature 1232
# 200 OK
# temperature 1233
# 200 OK
# temperature 1234
# 200 OK
# temperature 1235
# 200 OK
# temperature 1236
# 200 OK
# temperature 1237
# 200 OK
# temperature 1238
# 200 OK
# temperature 1239
# 200 OK
# temperature 1240
# 200 OK
# temperature 1241
# 200 OK
# temperature 1242
# 200 OK
# temperature 1243
# 200 OK
# temperature 1244
# 200 OK
# temperature 1245
# 200 OK
# temperature 1246
# 200 OK
# temperature 1247
# 200 OK
# temperature 1248
# 200 OK
# temperature 1249
# 200 OK
# temperature 1250
# 200 OK
# temperature 1251
# 200 OK
# temperature 1252
# 200 OK
# temperature 1253
# 200 OK
# temperature 1254
# 200 OK
# temperature 1255
# 200 OK
# temperature 1256
# 200 OK
# temperature 1257
# 200 OK
# temperature 1258
# 200 OK
# temperature 1259
# 200 OK
# temperature 1260
# 200 OK
# temperature 1261
# 200 OK
# temperature 1262
# 200 OK
# temperature 1263
# 200 OK
# temperature 1264
# 200 OK
# temperature 1265
# 200 OK
# temperature 1266
# 200 OK
# temperature 1267
# 200 OK
# temperature 1268
# 200 OK
# temperature 1269
# 200 OK
# temperature 1270
# 200 OK
# temperature 1271
# 200 OK
# temperature 1272
# 200 OK
# temperature 1273
# 200 OK
# temperature 1274
# 200 OK
# temperature 1275
# 200 OK
# temperature 1276
# 200 OK
# temperature 1277
# 200 OK
# temperature 1278
# 200 OK
# temperature 1279
# 200 OK
# temperature 1280
# 200 OK
# temperature 1281
# 200 OK
# temperature 1282
# 200 OK
# temperature 1283
# 200 OK
# temperature 1284
# 200 OK
# temperature 1285
# 200 OK
# temperature 1286
# 200 OK
# temperature 1287
# 200 OK
# temperature 1288
# 200 OK
# temperature 1289
# 200 OK
# temperature 1290
# 200 OK
# temperature 1291
# 200 OK
# temperature 1292
# 200 OK
# temperature 1293
# 200 OK
# temperature 1294
# 200 OK
# temperature 1295
# 200 OK
# temperature 1296
# 200 OK
# temperature 1297
# 200 OK
# temperature 1298
# 200 OK
# temperature 1299
# 200 OK
# temperature 1300
# 200 OK
# temperature 1301
# 200 OK
# temperature 1302
# 200 OK
# temperature 1303
# 200 OK
# temperature 1304
# 200 OK
# temperature 1305
# 200 OK
# temperature 1306
# 200 OK
# temperature 1307
# 200 OK
# temperature 1308
# 200 OK
# temperature 1309
# 200 OK
# temperature 1310
# 200 OK
# temperature 1311
# 200 OK
# temperature 1312
# 200 OK
# temperature 1313
# 200 OK
# temperature 1314
# 200 OK
# temperature 1315
# 200 OK
# temperature 1316
# 200 OK
# temperature 1317
# 200 OK
# temperature 1318
# 200 OK
# temperature 1319
# 200 OK
# temperature 1320
# 200 OK
# temperature 1321
# 200 OK
# temperature 1322
# 200 OK
# temperature 1323
# 200 OK
# temperature 1324
# 200 OK
# temperature 1325
# 200 OK
# temperature 1326
# 200 OK
# temperature 1327
# 200 OK
# temperature 1328
# 200 OK
# temperature 1329
# 200 OK
# temperature 1330
# 200 OK
# temperature 1331
# 200 OK
# temperature 1332
# 200 OK
# temperature 1333
# 200 OK
# temperature 1334
# 200 OK
# temperature 1335
# 200 OK
# temperature 1336
# 200 OK
# temperature 1337
# 200 OK
# temperature 1338
# 200 OK
# temperature 1339
# 200 OK
# temperature 1340
# 200 OK
# temperature 1341
# 200 OK
# temperature 1342
# 200 OK
# temperature 1343
# 200 OK
# temperature 1344
# 200 OK
# temperature 1345
# 200 OK
# temperature 1346
# 200 OK
# temperature 1347
# 200 OK
# temperature 1348
# 200 OK
# temperature 1349
# 200 OK
# temperature 1350
# 200 OK
# temperature 1351
# 200 OK
# temperature 1352
# 200 OK
# temperature 1353
# 200 OK
# temperature 1354
# 200 OK
# temperature 1355
# 200 OK
# temperature 1356
# 200 OK
# temperature 1357
# 200 OK
# temperature 1358
# 200 OK
# temperature 1359
# 200 OK
# temperature 1360
# 200 OK
# temperature 1361
# 200 OK
# temperature 1362
# 200 OK
# temperature 1363
# 200 OK
# temperature 1364
# 200 OK
# temperature 1365
# 200 OK
# temperature 1366
# 200 OK
# temperature 1367
# 200 OK
# temperature 1368
# 200 OK
# temperature 1369
# 200 OK
# temperature 1370
# 200 OK
# temperature 1371
# 200 OK
# temperature 1372
# 200 OK
# temperature 1373
# 200 OK
# temperature 1374
# 200 OK
# temperature 1375
# 200 OK
# temperature 1376
# 200 OK
# temperature 1377
# 200 OK
# temperature 1378
# 200 OK
# temperature 1379
# 200 OK
# temperature 1380
# 200 OK
# temperature 1381
# 200 OK
# temperature 1382
# 200 OK
# temperature 1383
# 200 OK
# temperature 1384
# 200 OK
# temperature 1385
# 200 OK
# temperature 1386
# 200 OK
# temperature 1387
# 200 OK
# temperature 1388
# 200 OK
# temperature 1389
# 200 OK
# temperature 1390
# 200 OK
# temperature 1391
# 200 OK
# temperature 1392
# 200 OK
# temperature 1393
# 200 OK
# temperature 1394
# 200 OK
# temperature 1395
# 200 OK
# temperature 1396
# 200 OK
# temperature 1397
# 200 OK
# temperature 1398
# 200 OK
# temperature 1399
# 200 OK
# temperature 1400
# 200 OK
# temperature 1401
# 200 OK
# temperature 1402
# 200 OK
# temperature 1403
# 200 OK
# temperature 1404
# 200 OK
# temperature 1405
# 200 OK
# temperature 1406
# 200 OK
# temperature 1407
